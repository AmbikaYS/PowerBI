# %% [markdown]
# <a href="https://colab.research.google.com/github/AmbikaYS/PowerBI/blob/main/AmazonSalesRecords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the required libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick  
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading the data file
asr=pd.read_csv('/content/AmazonSalesRecords(2).csv')

# %%
asr.head(5)
# Out:
#                               Region                Country         ItemType  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   SalesChannel OrderPriority   OrderDate    OrderID    ShipDate  UnitsSold  \
# 0      Offline             H  05-28-2010  669165933   6/27/2010       9925
# 1       Online             C  08-22-2012  963881480   9/15/2012       2804
# 2      Offline             L  05-02-2014  341417157  05-08-2014       1779
# 3       Online             C  06-20-2014  514321792  07-05-2014       8102
# 4      Offline             L  02-01-2013  115456712  02-06-2013       5062
#
# ...

# %%
asr.describe()
# Out:
#             OrderID    UnitsSold   UnitPrice    UnitCost  TotalRevenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000  1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000  1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181  1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000  4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000  2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000  7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000  2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000  5.997055e+06
#
#           TotalCost   TotalProfit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
# Shows the descriptive statistics of numerical values of data frame
75% customers bought 9925 units on a particular product id,
the Maximum profit earned is 1.719

# %%
asr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         100 non-null    object
#  1   Country        100 non-null    object
#  2   ItemType       100 non-null    object
#  3   SalesChannel   100 non-null    object
#  4   OrderPriority  100 non-null    object
#  5   OrderDate      100 non-null    object
#  6   OrderID        100 non-null    int64
#  7   ShipDate       100 non-null    object
#  8   UnitsSold      100 non-null    int64
#  9   UnitPrice      100 non-null    float64
#  10  UnitCost       100 non-null    float64
#  11  TotalRevenue   100 non-null    float64
#  12  TotalCost      100 non-null    float64
#  13  TotalProfit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
asr.columns.values
# Out:
# array(['Region', 'Country', 'ItemType', 'SalesChannel', 'OrderPriority',
#        'OrderDate', 'OrderID', 'ShipDate', 'UnitsSold', 'UnitPrice',
#        'UnitCost', 'TotalRevenue', 'TotalCost', 'TotalProfit'],
#       dtype=object)

# %%
asr['SalesChannel'].value_counts().plot(kind='barh', figsize=(8, 6))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
#Insight:both channels are having no difference

# %%
asr['OrderPriority'].value_counts().plot(kind='barh', figsize=(8, 6))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
# Orders with high priority is more than others

# %%
asr['ItemType'].value_counts().plot(kind='barh', figsize=(8, 6))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
# Officesupplis,Cosmetics,Cloths are more than others

# %%
asr['Region'].value_counts().plot(kind='barh', figsize=(8, 6))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
# Orders from Sub-saharan Africa is more than others

# %%
asr['Country'].value_counts().plot(kind='barh', figsize=(20, 30))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
asr['Region'].value_counts()
# Out:
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: Region, dtype: int64

# %%
100*asr['Region'].value_counts()/len(asr['Region'])
# Out:
# Sub-Saharan Africa                   36.0
# Europe                               22.0
# Australia and Oceania                11.0
# Asia                                 11.0
# Middle East and North Africa         10.0
# Central America and the Caribbean     7.0
# North America                         3.0
# Name: Region, dtype: float64

# %%
#Data is highely imbalanced the ratio is 36:22:11:11:10:7:3
Not getting anything particular, so we need to analyse the other columns such as Totalprofit.

# %%
# Concise Summary of the dataframe, as we have too many columns, we are using the verbose = True mode)
asr.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         100 non-null    object
#  1   Country        100 non-null    object
#  2   ItemType       100 non-null    object
#  3   SalesChannel   100 non-null    object
#  4   OrderPriority  100 non-null    object
#  5   OrderDate      100 non-null    object
#  6   OrderID        100 non-null    int64
#  7   ShipDate       100 non-null    object
#  8   UnitsSold      100 non-null    int64
#  9   UnitPrice      100 non-null    float64
#  10  UnitCost       100 non-null    float64
#  11  TotalRevenue   100 non-null    float64
#  12  TotalCost      100 non-null    float64
#  13  TotalProfit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
# Since there are no missing values,no need to handle missing values

# %%
missing = pd.DataFrame((asr.isnull().sum())*100/asr.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
asr1=asr.copy()

# %%
# Data Cleaning: 

#Since we dont have any missig value and data type changes in column, no need to perform data cleaning,

# %% [markdown]
# #Data Exploration
#
# # Plot distribution of individual predictor by Total profit

# %%
asr1.head()
# Out:
#                  Country         ItemType OrderPriority   OrderDate  \
# 0                 Tuvalu        Baby Food             H  05-28-2010
# 1                Grenada           Cereal             C  08-22-2012
# 2                 Russia  Office Supplies             L  05-02-2014
# 3  Sao Tome and Principe           Fruits             C  06-20-2014
# 4                 Rwanda  Office Supplies             L  02-01-2013
#
#      ShipDate  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0   6/27/2010       9925     255.28    159.42    2533654.00  1582243.50
# 1   9/15/2012       2804     205.70    117.11     576782.80   328376.44
# 2  05-08-2014       1779     651.21    524.96    1158502.59   933903.84
# 3  07-05-2014       8102       9.33      6.92      75591.66    56065.84
# 4  02-06-2013       5062     651.21    524.96    3296425.02  2657347.52
#
#    TotalProfit
# 0    951410.50
# 1    248406.36
# 2    224598.75
# 3     19525.82
# 4    639077.50

# %%
#drop column customerID and tenure
asr1.drop(columns= ['OrderID','ShipDate','OrderDate'], axis=1, inplace=True)
asr1.head()
# Out:
#                               Region                Country         ItemType  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   SalesChannel OrderPriority  UnitsSold  UnitPrice  UnitCost  TotalRevenue  \
# 0      Offline             H       9925     255.28    159.42    2533654.00
# 1       Online             C       2804     205.70    117.11     576782.80
# 2      Offline             L       1779     651.21    524.96    1158502.59
# 3       Online             C       8102       9.33      6.92      75591.66
# 4      Offline             L       5062     651.21    524.96    3296425.02
#
#     TotalCost  TotalProfit
# ...

# %% [markdown]
# #Removing unwanted columns which has no particular relevance to derive the insights

# %%
for i, predictor in enumerate(asr1.drop(columns=['SalesChannel','UnitPrice','UnitCost'])):
    plt.figure(i,figsize=(15,10))
    sns.countplot(data=asr1, x=predictor, hue='SalesChannel')

# %% [markdown]
# Convert the target variable 'Churn' in a binary numeric variable i.e. offline=1,online-0

# %%
asr1['SalesChannel'] = np.where(asr1.SalesChannel == 'Offline',1,0)

# %%
asr1.head()
# Out:
#                               Region                Country         ItemType  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#    SalesChannel OrderPriority  UnitsSold  UnitPrice  UnitCost  TotalRevenue  \
# 0             1             H       9925     255.28    159.42    2533654.00
# 1             0             C       2804     205.70    117.11     576782.80
# 2             1             L       1779     651.21    524.96    1158502.59
# 3             0             C       8102       9.33      6.92      75591.66
# 4             1             L       5062     651.21    524.96    3296425.02
#
#     TotalCost  TotalProfit
# ...

# %% [markdown]
# 3. Convert all the categorical variables into dummy variables

# %%
asr1dummies = pd.get_dummies(asr1)
asr1dummies.head()
# Out:
#    SalesChannel  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0             1       9925     255.28    159.42    2533654.00  1582243.50
# 1             0       2804     205.70    117.11     576782.80   328376.44
# 2             1       1779     651.21    524.96    1158502.59   933903.84
# 3             0       8102       9.33      6.92      75591.66    56065.84
# 4             1       5062     651.21    524.96    3296425.02  2657347.52
#
#    TotalProfit  Region_Asia  Region_Australia and Oceania  \
# 0    951410.50            0                             1
# 1    248406.36            0                             0
# 2    224598.75            0                             0
# 3     19525.82            0                             0
# 4    639077.50            0                             0
#
#    Region_Central America and the Caribbean  ...  ItemType_Household  \
# 0                                         0  ...                   0
# ...

# %% [markdown]
# 9. * Relationship between Region and Total Profit

# %%
sns.lmplot(data=asr1dummies, x='UnitsSold', y='TotalProfit', fit_reg=False)

# %% [markdown]
# Total Proft increses when number of unitsold increses

# %%
Mth = sns.kdeplot(asr1dummies.TotalPrice[(asr1dummies["SalesChannel"] == 1) ],
                color="Red", shade = True)
Mth = sns.kdeplot(asr1dummies.TotalPrice[(asr1dummies["SalesChannel"] == 0) ],
                ax =Mth, color="Blue", shade= True)
Mth.legend(["Offline","Online"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('ItemType')
Mth.set_title('OrderPriority by SalesChannel')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5f9bf585e9ef> in <cell line: 1>()
# ----> 1 Mth = sns.kdeplot(asr1dummies.TotalPrice[(asr1dummies["SalesChannel"] == 1) ],
#       2                 color="Red", shade = True)
#       3 Mth = sns.kdeplot(asr1dummies.TotalPrice[(asr1dummies["SalesChannel"] == 0) ],
#       4                 ax =Mth, color="Blue", shade= True)
#       5 Mth.legend(["Offline","Online"],loc='upper right')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'TotalPrice'

# %%
asr1dummies.head(2)
# Out:
#    SalesChannel  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0             1       9925     255.28    159.42     2533654.0  1582243.50
# 1             0       2804     205.70    117.11      576782.8   328376.44
#
#    TotalProfit  Region_Asia  Region_Australia and Oceania  \
# 0    951410.50            0                             1
# 1    248406.36            0                             0
#
#    Region_Central America and the Caribbean  ...  ItemType_Household  \
# 0                                         0  ...                   0
# 1                                         1  ...                   0
#
#    ItemType_Meat  ItemType_Office Supplies  ItemType_Personal Care  \
# 0              0                         0                       0
# 1              0                         0                       0
#
#    ItemType_Snacks  ItemType_Vegetables  OrderPriority_C  OrderPriority_H  \
# ...

# %%
plt.figure(figsize=(20,8))
asr1dummies.corr()['TotalProfit'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **Derived Insight**
#
# High Profit is seen in Total cost,ItemType-Cosmetics,Units Sold,Unit Price,
# Unit Cost, Country_Pakistan,Country_Samoa,ItemType_Houehold,Country_Iceland,Country_Romania,OrderPriority_High,Country_Sri Lanka,Iran,Dijibouti,Lithuania
#
# Low Profit is seeen the case of ItemType Fruits,Personal care,Beverages,Order_Priority C,Vegitables.
#
# Factors like Country doesnot give any insights
#
# The same insights are evident from Heatmap as well

# %%
plt.figure(figsize=(9,7))
sns.heatmap(asr1dummies.corr(), cmap="Paired")
# Out:
# <Axes: >

# %% [markdown]
# **Bivariate Analysis**

# %%
target0=asr1.loc[asr1["SalesChannel"]==0]
target1=asr1.loc[asr1["SalesChannel"]==1]

# %%
len(target0)
# Out:
# 50

# %%
len(target1)
# Out:
# 50

# %%
def uniplot(df,col,title,hue =None):
    
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30
    
    
    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright') 
        
    plt.show()

# %%
uniplot(target1,col='Country',title='Distribution of Total Profit through OrderPriority',hue='OrderPriority')

# %% [markdown]
# The Country Gambia has high order priority through offline

# %%
uniplot(target0,col='Country',title='Distribution of Country through OrderPriority',hue='OrderPriority')

# %% [markdown]
# Insights:
#
# Azarbeijin, Balgeriya countries have medium_orderpriorty through online purchases

# %%
asr1.head(2)
# Out:
#                               Region  Country   ItemType  SalesChannel  \
# 0              Australia and Oceania   Tuvalu  Baby Food             1
# 1  Central America and the Caribbean  Grenada     Cereal             0
#
#   OrderPriority  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0             H       9925     255.28    159.42     2533654.0  1582243.50
# 1             C       2804     205.70    117.11      576782.8   328376.44
#
#    TotalProfit
# 0    951410.50
# 1    248406.36

# %%
uniplot(target1,col='TotalProfit',title='Distribution of TotalProfit for ItemType',hue='ItemType')

# %% [markdown]
# There is no particualr impact based on offline sales of Item Types for Total Prpfit

# %%
uniplot(target0,col='TotalProfit',title='Distribution of TotalProfit for ItemType',hue='ItemType')

# %%
asr1.head(2)
# Out:
#                               Region  Country   ItemType  SalesChannel  \
# 0              Australia and Oceania   Tuvalu  Baby Food             1
# 1  Central America and the Caribbean  Grenada     Cereal             0
#
#   OrderPriority  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  \
# 0             H       9925     255.28    159.42     2533654.0  1582243.50
# 1             C       2804     205.70    117.11      576782.8   328376.44
#
#    TotalProfit
# 0    951410.50
# 1    248406.36

# %% [markdown]
# Conclusion:
#
#     Derived Insights:
#
#         Country,SalesChannel,OrderPriority have high impact on Total Profit.
#
#         Region, Item Type doesnot have any impact Total Profit.
